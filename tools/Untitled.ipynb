# %%
## standart libraries
import os,sys
import numpy as np

# xarray
import xarray as xr

# time
import datetime
import netCDF4
import cftime

# plot
import cartopy.crs as ccrs
import cartopy.feature as ccf
import matplotlib.pyplot as plt
from matplotlib.colors import Colormap
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
import matplotlib.cm as cm
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.colors import from_levels_and_colors
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# for jupyter notebook display

# %matplotlib inline

# %%
diri="/Users/leroux/Downloads/"
fili="GM_eORCA025.L75-IMHOTEP.GAIc_1d_1993-2018.nc"
GM = xr.open_dataset(diri+fili,decode_times=True)
GM
# Out:
# <xarray.Dataset>
# Dimensions:          (y: 1, x: 1, gdept: 1, time_counter: 9496)
# Coordinates:
#   * gdept            (gdept) float32 0.5058
#   * time_counter     (time_counter) datetime64[ns] 1993-01-01T12:00:00 ... 20...
# Dimensions without coordinates: y, x
# Data variables:
#     nav_lon          (y, x) float32 ...
#     nav_lat          (y, x) float32 ...
#     mean_sossheig    (time_counter, y, x) float32 ...
#     mean_3Dsossheig  (time_counter, y, x) float32 ...
# Attributes:
#     start_date:        19580101
#     output_frequency:  1d
#     CONFIG:            eORCA025.L75
#     CASE:              IMHOTEP.GAIc
#     history:           Wed Oct 18 16:31:36 2023: ncrcat -4 -L 4 -o GM_eORCA02...
#     NCO:               netCDF Operators version 4.9.3 (Homepage = http://nco....

# %%
(2018-1993+1)*365
# Out:
# 9490

# %%
GM.mean_sossheig.isel(time_counter=slice(9*365,9496)).plot()
