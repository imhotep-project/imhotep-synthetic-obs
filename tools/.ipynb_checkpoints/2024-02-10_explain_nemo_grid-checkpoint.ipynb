# %% [markdown]
# Demo how to use the NEMO grid infos to compute the area of each grid cell and to sum all of them to get the surface of the Earth

# %%
## standart libraries
import os,sys
import numpy as np

# xarray
import xarray as xr

# time
import datetime
import netCDF4
import cftime

# plot
import cartopy.crs as ccrs
import cartopy.feature as ccf
import matplotlib.pyplot as plt
from matplotlib.colors import Colormap
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
import matplotlib.cm as cm
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.colors import from_levels_and_colors
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# for jupyter notebook display

# %matplotlib inline

# %% [markdown]
# ## 1. Read `mesh_hgr.nc` file (grid info from NEMO)

# %%
diri="/Users/leroux/Downloads/"
fili="mesh_hgr.nc"
datagrid = xr.open_dataset(diri+fili,decode_times=False)
datagrid
# Out:
# <xarray.Dataset>
# Dimensions:       (y: 1207, x: 1442, nav_lev: 75, time_counter: 1)
# Coordinates:
#   * nav_lev       (nav_lev) float32 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * time_counter  (time_counter) float64 0.0
# Dimensions without coordinates: y, x
# Data variables: (12/51)
#     nav_lon       (y, x) float32 ...
#     nav_lat       (y, x) float32 ...
#     jpiglo        int32 ...
#     jpjglo        int32 ...
#     jpkglo        int32 ...
#     jperio        int32 ...
#     ...            ...
#     e3uw_0        (time_counter, nav_lev, y, x) float64 ...
#     e3vw_0        (time_counter, nav_lev, y, x) float64 ...
#     gdept_1d      (time_counter, nav_lev) float64 ...
#     gdepw_1d      (time_counter, nav_lev) float64 ...
#     gdept_0       (time_counter, nav_lev, y, x) float64 ...
#     gdepw_0       (time_counter, nav_lev, y, x) float64 ...
# Attributes:
#     file_name:  mesh_mask.nc
#     TimeStamp:  09/04/2021 19:22:15 +0200

# %% [markdown]
# ## 2. Area of the grid cells:
# e1t and e2t give the dimensions of each grid cell in X and Y dimention.
#
# The area of each grid cell is thus given by e1*e2 (in m2).
#
# Note that e3t gives the height of the cell in case you need its volume.

# %%
# area of grid cells in km: e1*e2 is in m2. Divide by 1e6 to convert to km2 
areat = (datagrid.e1t*datagrid.e2t)/1e6

# %% [markdown]
# ## 3. Compute the surface of the Earth as a check:

# %%
# Surface of the Earth? Should get 510*1e6 km2
areat.sum()
# Out:
# <xarray.DataArray ()>
# array(5.08758525e+08)
